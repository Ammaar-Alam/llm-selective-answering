# %% [markdown]
# # Project Overview
#
# This notebook is for the high-level data science story: question, datasets, decision rule, and smoke-test outputs.

# %%
from pathlib import Path
import pandas as pd

Path.cwd()
